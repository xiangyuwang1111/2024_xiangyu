# %%
import requests
from requests import Response
youbike_url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
try:
    response:Response = requests.get(youbike_url)
except:
    print("Internet有問題")
else:
    print("連線沒有問題")

if response.status_code == 200:
    print("資料下載成功")
else:
    print("資料下載有問題")
# Out:
# 連線沒有問題
# 資料下載成功

# %%
from pprint import pprint
response.encoding = 'utf-8'
#取出純文字的json
#pprint(response.text)

# %%
data:list[dict] = response.json()

# %%
import pandas as pd
df1=pd.DataFrame(data,columns=['sna', 'sarea', 'ar', 'total', 'available_rent_bikes', 'mday', 'available_return_bikes'])
df1
# Out:
#                            sna   sarea             ar  total  \
# 0           YouBike2.0_捷運科技大樓站     大安區    復興南路二段235號前     28
# 1       YouBike2.0_復興南路二段273號前     大安區   復興南路二段273號西側     21
# 2         YouBike2.0_國北教大實小東側門     大安區    和平東路二段96巷7號     16
# 3            YouBike2.0_和平公園東側     大安區  和平東路二段118巷33號     11
# 4         YouBike2.0_辛亥復興路口西北側     大安區     復興南路二段368號     16
# ...                        ...     ...            ...    ...
# 1425      YouBike2.0_臺大總圖書館西南側  臺大公館校區       臺大圖書館西南側     30
# 1426        YouBike2.0_臺大黑森林西側  臺大公館校區        臺大霖澤館南側     20
# 1427        YouBike2.0_臺大獸醫館南側  臺大公館校區       臺大獸醫系館南側     24
# 1428      YouBike2.0_臺大新體育館東南側  臺大公館校區        臺大體育館東側     40
# 1429  YouBike2.0_臺大明達館北側(員工宿舍)  臺大公館校區       明達館北側前空地     18
#
#       available_rent_bikes                 mday  available_return_bikes
# 0                        9  2024-07-11 15:31:55                      19
# 1                       20  2024-07-11 15:31:21                       1
# 2                       11  2024-07-11 15:33:20                       5
# 3                        3  2024-07-11 15:31:55                       8
# 4                       12  2024-07-11 15:28:20                       4
# ...                    ...                  ...                     ...
# 1425                    18  2024-07-11 15:13:19                       1
# 1426                     6  2024-07-11 15:22:20                      14
# 1427                     8  2024-07-11 15:29:19                       8
# 1428                    23  2024-07-11 15:25:22                       7
# 1429                     0  2024-07-11 15:24:14                      18
#
# [1430 rows x 7 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1430 entries, 0 to 1429
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   站點名稱    1430 non-null   object
#  1   行政區     1430 non-null   object
#  2   地址      1430 non-null   object
#  3   車輛總數    1430 non-null   int64
#  4   可借      1430 non-null   int64
#  5   日期      1430 non-null   object
#  6   可還      1430 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 78.3+ KB

# %%
df2=df1.rename(columns={'sna':'站點名稱', 'sarea':'行政區', 'ar': '地址', 'total':'車輛總數', 'available_rent_bikes':'可借', 'mday':'日期', 'available_return_bikes':'可還'})
df2
# Out:
#                           站點名稱     行政區             地址  車輛總數  可借  \
# 0           YouBike2.0_捷運科技大樓站     大安區    復興南路二段235號前    28   9
# 1       YouBike2.0_復興南路二段273號前     大安區   復興南路二段273號西側    21  20
# 2         YouBike2.0_國北教大實小東側門     大安區    和平東路二段96巷7號    16  11
# 3            YouBike2.0_和平公園東側     大安區  和平東路二段118巷33號    11   3
# 4         YouBike2.0_辛亥復興路口西北側     大安區     復興南路二段368號    16  12
# ...                        ...     ...            ...   ...  ..
# 1425      YouBike2.0_臺大總圖書館西南側  臺大公館校區       臺大圖書館西南側    30  18
# 1426        YouBike2.0_臺大黑森林西側  臺大公館校區        臺大霖澤館南側    20   6
# 1427        YouBike2.0_臺大獸醫館南側  臺大公館校區       臺大獸醫系館南側    24   8
# 1428      YouBike2.0_臺大新體育館東南側  臺大公館校區        臺大體育館東側    40  23
# 1429  YouBike2.0_臺大明達館北側(員工宿舍)  臺大公館校區       明達館北側前空地    18   0
#
#                        日期  可還
# 0     2024-07-11 15:31:55  19
# 1     2024-07-11 15:31:21   1
# 2     2024-07-11 15:33:20   5
# 3     2024-07-11 15:31:55   8
# 4     2024-07-11 15:28:20   4
# ...                   ...  ..
# 1425  2024-07-11 15:13:19   1
# 1426  2024-07-11 15:22:20  14
# 1427  2024-07-11 15:29:19   8
# 1428  2024-07-11 15:25:22   7
# 1429  2024-07-11 15:24:14  18
#
# [1430 rows x 7 columns]
